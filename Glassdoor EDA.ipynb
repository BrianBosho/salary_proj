# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('500jobs_cleaned.csv')
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0              Job Title      Salary Estimate  \
# 0             1           1         Data Scientist    $85.00 /hr (est.)
# 1             2           2     Data Scientist III   $80,000 /yr (est.)
# 2             3           3         Data Scientist  $115,000 /yr (est.)
# 3             4           4  Junior Data Scientist  $100,000 /yr (est.)
# 4             5           5         Data Scientist    $77.50 /hr (est.)
#
#          Job Description  Rating                        Company Name  \
# 0         Data Scientist     4.3                        Infologitech
# 1     Data Scientist III     4.4  GTA (Global Technology Associates)
# 2         Data Scientist    -1.0           3G Federal Solutions, LLC
# 3  Junior Data Scientist    -1.0                      Talentheed Inc
# 4         Data Scientist     4.6                      Kani Solutions
#
#         Location   Headquarters                  Size  ...  Type of ownership  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Job Title', 'Salary Estimate',
#        'Job Description', 'Rating', 'Company Name', 'Location', 'Headquarters',
#        'Size', 'Founded', 'Type of ownership', 'Industry', 'Sector', 'Revenue',
#        'Competitors', 'hourly', 'yearly', 'Salary', 'age', 'state'],
#       dtype='object')

# %%
df['hourly'].value_counts()
# Out:
# 0    411
# 1     41
# Name: hourly, dtype: int64

# %%
df['Salary'] = df['Salary'].apply(lambda x: x.split('.')[0])
df['Salary'] = df['Salary'].apply(lambda x: x.split(',')[0])
df['Salary'] = df['Salary'].astype('int')

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0              Job Title      Salary Estimate  \
# 0             1           1         Data Scientist    $85.00 /hr (est.)
# 1             2           2     Data Scientist III   $80,000 /yr (est.)
# 2             3           3         Data Scientist  $115,000 /yr (est.)
# 3             4           4  Junior Data Scientist  $100,000 /yr (est.)
# 4             5           5         Data Scientist    $77.50 /hr (est.)
#
#          Job Description  Rating                        Company Name  \
# 0         Data Scientist     4.3                        Infologitech
# 1     Data Scientist III     4.4  GTA (Global Technology Associates)
# 2         Data Scientist    -1.0           3G Federal Solutions, LLC
# 3  Junior Data Scientist    -1.0                      Talentheed Inc
# 4         Data Scientist     4.6                      Kani Solutions
#
#         Location   Headquarters                  Size  ...  Type of ownership  \
# ...

# %%
df['Salary'] = df.apply(lambda x: x.Salary*2000 if x.hourly==1 else x.Salary*1000, axis=1)
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0              Job Title      Salary Estimate  \
# 0             1           1         Data Scientist    $85.00 /hr (est.)
# 1             2           2     Data Scientist III   $80,000 /yr (est.)
# 2             3           3         Data Scientist  $115,000 /yr (est.)
# 3             4           4  Junior Data Scientist  $100,000 /yr (est.)
# 4             5           5         Data Scientist    $77.50 /hr (est.)
#
#          Job Description  Rating                        Company Name  \
# 0         Data Scientist     4.3                        Infologitech
# 1     Data Scientist III     4.4  GTA (Global Technology Associates)
# 2         Data Scientist    -1.0           3G Federal Solutions, LLC
# 3  Junior Data Scientist    -1.0                      Talentheed Inc
# 4         Data Scientist     4.6                      Kani Solutions
#
#         Location   Headquarters                  Size  ...  Type of ownership  \
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0.1  Unnamed: 0      Rating      Founded  Competitors  \
# count    452.000000  452.000000  452.000000   452.000000        452.0
# mean     250.042035  250.042035    2.963053  1304.692478         -1.0
# std      144.963366  144.963366    2.075532   940.150797          0.0
# min        1.000000    1.000000   -1.000000    -1.000000         -1.0
# 25%      124.750000  124.750000    2.200000    -1.000000         -1.0
# 50%      250.500000  250.500000    3.900000  1963.000000         -1.0
# 75%      375.250000  375.250000    4.200000  2005.000000         -1.0
# max      499.000000  499.000000    5.000000  2021.000000         -1.0
#
#            hourly      yearly         Salary         age
# count  452.000000  452.000000     452.000000  452.000000
# mean     0.090708    0.907080  108101.769912   27.714602
# std      0.287512    0.290642   27342.425737   36.552431
# min      0.000000    0.000000   57000.000000   -1.000000
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Job Title', 'Salary Estimate',
#        'Job Description', 'Rating', 'Company Name', 'Location', 'Headquarters',
#        'Size', 'Founded', 'Type of ownership', 'Industry', 'Sector', 'Revenue',
#        'Competitors', 'hourly', 'yearly', 'Salary', 'age', 'state'],
#       dtype='object')

# %%
df.Rating.hist()
# Out:
# <AxesSubplot:>

# %%
df.Salary.hist()
# Out:
# <AxesSubplot:>

# %%
df.age.hist()
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = 'Salary')
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = 'Rating')
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Job Title', 'Salary Estimate',
#        'Job Description', 'Rating', 'Company Name', 'Location', 'Headquarters',
#        'Size', 'Founded', 'Type of ownership', 'Industry', 'Sector', 'Revenue',
#        'Competitors', 'hourly', 'yearly', 'Salary', 'age', 'state'],
#       dtype='object')

# %%
df_cat = df[['Job Title','state','Size','Type of ownership', 'Industry', 'Sector', 'Revenue']]
df_cat.head()
# Out:
#                Job Title   state                  Size  Type of ownership  \
# 0         Data Scientist  Remote                    -1                 -1
# 1     Data Scientist III      CO                    -1                 -1
# 2         Data Scientist  Remote                    -1                 -1
# 3  Junior Data Scientist  Remote                    -1                 -1
# 4         Data Scientist  Remote  201 to 500 Employees  Company - Private
#
#                                   Industry                  Sector  \
# 0                                       -1                      -1
# 1                                       -1                      -1
# 2                                       -1                      -1
# 3                                       -1                      -1
# 4  Information Technology Support Services  Information Technology
#
#                    Revenue
# 0                       -1
# 1                       -1
# 2                       -1
# ...

# %%
df_cat = df_cat[df_cat.Size != "-1"]
# df_cat.drop([df_cat.Size =="-1"], inplace=True, axis=)
df_cat.head()
# Out:
#                            Job Title   state                    Size  \
# 4                     Data Scientist  Remote    201 to 500 Employees
# 6   Data Scientist - Personalization      NJ  1001 to 5000 Employees
# 10                    Data Scientist      NY  1001 to 5000 Employees
# 11                    Data Scientist      TX        10000+ Employees
# 12                    Data Scientist  Remote  1001 to 5000 Employees
#
#                  Type of ownership                                 Industry  \
# 4                Company - Private  Information Technology Support Services
# 6   Subsidiary or Business Segment                          Film Production
# 10                Company - Public          Insurance Agencies & Brokerages
# 11                Company - Public   Transportation Equipment Manufacturing
# 12               Company - Private  Information Technology Support Services
#
#                     Sector                   Revenue
# ...

# %%
df_cat.describe()
# Out:
#              Job Title state              Size Type of ownership  \
# count              298   298               298               298
# unique              23    14                 7                 6
# top     Data Scientist    NY  10000+ Employees  Company - Public
# freq                62    84               126               158
#
#                        Industry                  Sector  \
# count                       298                     298
# unique                       22                      12
# top     Internet & Web Services  Information Technology
# freq                         57                      97
#
#                          Revenue
# count                        298
# unique                        11
# top     Unknown / Non-Applicable
# freq                          94

# %%
for column in df_cat.columns:  
    counts = df_cat[column].value_counts()
    chart = sns.barplot(x=counts.index ,y=counts)
    chart.set_xticklabels(chart.get_xticklabels(), 
                              rotation=90, 
                              horizontalalignment='right')
    plt.show()

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Job Title', 'Salary Estimate',
#        'Job Description', 'Rating', 'Company Name', 'Location', 'Headquarters',
#        'Size', 'Founded', 'Type of ownership', 'Industry', 'Sector', 'Revenue',
#        'Competitors', 'hourly', 'yearly', 'Salary', 'age', 'state'],
#       dtype='object')

# %%
pd.pivot_table(df, index= ['Size', 'Sector'], values = 'Salary')
# Out:
#                                                                Salary
# Size                    Sector
# -1                      -1                              110863.636364
# 1 to 50 Employees       Healthcare                       59000.000000
#                         Information Technology          122000.000000
# 10000+ Employees        Education                       110000.000000
#                         Financial Services               92375.000000
#                         Healthcare                       99000.000000
#                         Information Technology          120000.000000
#                         Insurance                       124000.000000
#                         Manufacturing                   111000.000000
#                         Media & Communication            91000.000000
#                         Pharmaceutical & Biotechnology  112000.000000
#                         Restaurants & Food Service       77000.000000
# ...

# %%
pd.pivot_table(df, index=['state','Sector'], values = 'Salary', aggfunc = 'count').sort_values('state', ascending= True)
# Out:
#                                          Salary
# state    Sector
#  CA      -1                                   7
#          Information Technology               2
#          Insurance                            1
#          Media & Communication                2
#          Retail & Wholesale                   1
#  CO      -1                                  18
#          Telecommunications                   1
#  FL      -1                                   6
#          Media & Communication                5
#  GA      Retail & Wholesale                  11
#          -1                                   1
#          Information Technology              15
#  IA      Financial Services                   1
#  IN      Pharmaceutical & Biotechnology      15
#  MD      -1                                   4
#  NC      -1                                   5
#  NJ      Media & Communication                1
#  NY      Manufacturing                       14
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Job Title', 'Salary Estimate',
#        'Job Description', 'Rating', 'Company Name', 'Location', 'Headquarters',
#        'Size', 'Founded', 'Type of ownership', 'Industry', 'Sector', 'Revenue',
#        'Competitors', 'hourly', 'yearly', 'Salary', 'age', 'state'],
#       dtype='object')

# %%
df_pivots = df[['Job Title','Rating','Sector','Revenue', 'age', 'state','Type of ownership','Size']]

# %%
for x in df_pivots.columns:
    print(x)
    print(pd.pivot_table(df, index =x, values='Salary').sort_values('Salary', ascending=False))
# Out:
# Job Title
#                                                            Salary
# Job Title
# Senior Data Scientist                               165000.000000
# Data Scientist (Remote)                             154000.000000
# Senior or Staff Data Scientist, Spotify Adverti...  144000.000000
# Web3 Wallet Data Scientist                          140000.000000
# Data Scientist, Data Science & Modeling             134000.000000
# Data Scientist                                      125516.393443
# Data Scientist II - 100% Remote                     123000.000000
# Marketing Data Scientist                            120000.000000
# Data Scientist - (Remote)                           112000.000000
# Data Scientist, Personalization                     112000.000000
# (Junior / Senior) Data Scientist - Sports Analy...  112000.000000
# DATA SCIENTIST                                      110000.000000
# Data Scientist II                                   109000.000000
# ...

# %%
pd.pivot_table(df, index ='Sector', columns='state', values='Salary')
# Out:
# state                                      CA             CO        FL  \
# Sector
# -1                              128571.428571   97777.777778  174000.0
# Education                                 NaN            NaN       NaN
# Financial Services                        NaN            NaN       NaN
# Healthcare                                NaN            NaN       NaN
# Information Technology          165000.000000            NaN       NaN
# Insurance                        90000.000000            NaN       NaN
# Management & Consulting                   NaN            NaN       NaN
# Manufacturing                             NaN            NaN       NaN
# Media & Communication           117000.000000            NaN   91000.0
# Pharmaceutical & Biotechnology            NaN            NaN       NaN
# Restaurants & Food Service                NaN            NaN       NaN
# Retail & Wholesale              105000.000000            NaN       NaN
# ...

# %%
# add wordcloud from the descriptions // Will have to do this for jiji as I am able to collect the relevant data
